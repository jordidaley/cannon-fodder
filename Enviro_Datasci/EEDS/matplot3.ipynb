# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(-2,2,100)
y = np.linspace(-2,2,100)

# %%
xx, yy = np.meshgrid(x, y)
xx.shape, yy.shape
# Out:
# ((100, 100), (100, 100))

# %%
plt.pcolormesh(xx)

# %%
plt.pcolormesh(yy)

# %%
r = np.sqrt(np.square(xx) + np.square(yy))
𝜑 = np.arctan2(yy,xx)

# %%
plt.pcolormesh(r)

# %%
plt.pcolormesh(𝜑)

# %%
f = (np.cos(4*r) ** 2) + (np.sin(4*𝜑) ** 2)

# %%
plt.pcolormesh(f)

# %%
f_ymean = f.mean(axis=0)
f_xmean = f.mean(axis=1)

# %%
plt.plot(x, f_ymean)

# %%
plt.plot(f_xmean, y)

# %% [markdown]
# ## 1.8 ???? plot mean of f in respect to phi as a function of r ????

# %%
import pooch
url = "https://www.ldeo.columbia.edu/~rpa/float_data_4901412.zip"
files = pooch.retrieve(url, processor=pooch.Unzip(), known_hash="2a703c720302c682f1662181d329c9f22f9f10e1539dc2d6082160a469165009")
files
# Out:
# ['/Users/jordidaley/Library/Caches/pooch/7e6685dbe2a3c0b0870f770f3ef413d9-float_data_4901412.zip.unzip/float_data/date.npy',
#  '/Users/jordidaley/Library/Caches/pooch/7e6685dbe2a3c0b0870f770f3ef413d9-float_data_4901412.zip.unzip/float_data/T.npy',
#  '/Users/jordidaley/Library/Caches/pooch/7e6685dbe2a3c0b0870f770f3ef413d9-float_data_4901412.zip.unzip/float_data/S.npy',
#  '/Users/jordidaley/Library/Caches/pooch/7e6685dbe2a3c0b0870f770f3ef413d9-float_data_4901412.zip.unzip/float_data/P.npy',
#  '/Users/jordidaley/Library/Caches/pooch/7e6685dbe2a3c0b0870f770f3ef413d9-float_data_4901412.zip.unzip/float_data/levels.npy',
#  '/Users/jordidaley/Library/Caches/pooch/7e6685dbe2a3c0b0870f770f3ef413d9-float_data_4901412.zip.unzip/float_data/lon.npy',
#  '/Users/jordidaley/Library/Caches/pooch/7e6685dbe2a3c0b0870f770f3ef413d9-float_data_4901412.zip.unzip/float_data/lat.npy']

# %%
temperature = np.load(files[1])

salinity = np.load(files[2])

pressure = np.load(files [3])

date = np.load(files[0])

latitude = np.load(files[6])

longitude = np.load(files[5])

depth_level = np.load(files[4])

# %%
np.shape(temperature)
# Out:
# (78, 75)

# %%
np.shape(salinity)
# Out:
# (78, 75)

# %%
np.shape(pressure)
# Out:
# (78, 75)

# %%
np.shape(date)
# Out:
# (75,)

# %%
np.shape(latitude)
# Out:
# (75,)

# %%
np.shape(longitude)
# Out:
# (75,)

# %%
np.shape(depth_level)
# Out:
# (78,)

# %% [markdown]
# 78 levels, 25 says recorded at each level

# %%
plt.plot(temperature)

# %%
plt.plot(salinity)

# %%
plt.plot(pressure)

# %%
t_mean = temperature.mean(axis=1)
t_std = temperature.std(axis=1)

# %%
s_mean = salinity.mean(axis=1)
s_std = salinity.std(axis=1)

# %%
p_mean = pressure.mean(axis=1)
p_std = pressure.std(axis=1)

# %%
plt.errorbar(depth_level, t_mean, t_std)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(depth_level, s_mean, s_std)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(depth_level, p_mean, p_std)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Each row (axis = 1) is a depth in this data, this the need to make them all based on the y not x axis

# %%
t_nanmean = np.nanmean(temperature, axis=1)
t_nanstd = np.nanstd(temperature, axis=1)
s_nanmean = np.nanmean(salinity, axis=1)
s_nanstd = np.nanstd(salinity, axis=1)
p_nanmean = np.nanmean(pressure,axis=1)
p_nanstd = np.nanstd(pressure, axis=1)

# %%
plt.errorbar(depth_level, t_nanmean, t_nanstd)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(depth_level, s_nanmean, s_nanstd)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(depth_level, p_nanmean, p_nanstd)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.scatter(longitude, latitude)
